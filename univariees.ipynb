# %% [markdown]
# # SETTING UP

# %% [markdown]
# 0. INSTALL AND IMPORT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. LOADING DATA

# %%
# Load Data from CSV
df = pd.read_csv('HPI_master.csv')

# %%
# Identify numerical and non-numerical columns
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
non_numerical_columns = df.select_dtypes(exclude=['float64', 'int64']).columns

# %% [markdown]
# # UNI-VARIEES ANALYSIS FOR NUMERICAL COLUMNS

# %%
# Univariate analysis for numerical columns
for column in numerical_columns:
    descriptive_stats = df[column].describe()
    mean_value = descriptive_stats['mean']
    median_value = df[column].median()
    mode_value = df[column].mode()[0]
    range_value = df[column].max() - df[column].min()
    variance_value = df[column].var()
    std_deviation_value = df[column].std()

    print(f'Descriptive Statistics for {column}:\n{descriptive_stats}\n')
    print(f'Mean(Moy): {mean_value}')
    print(f'Median: {median_value}')
    print(f'Mode: {mode_value}')
    print(f'Range: {range_value}')
    print(f'Variance: {variance_value}')
    print(f'Standard Deviation: {std_deviation_value}\n')

    # Histogram
    plt.hist(df[column], bins='auto', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

    # Box plot
    sns.boxplot(x=df[column])
    plt.title(f'Box Plot of {column}')
    plt.show()

    # Density plot
    sns.kdeplot(df[column], fill=True)
    plt.title(f'Density Plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.show()

    # Pie chart for numerical data (using bins)
    plt.figure(figsize=(8, 8))
    bins = pd.cut(df[column], bins=10, include_lowest=True)
    bin_counts = bins.value_counts()
    plt.pie(bin_counts, labels=bin_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'Pie Chart of {column}')
    plt.show()

    # Frequency table and cumulative frequency table
    frequency_table = pd.DataFrame(df[column].value_counts())
    cumulative_frequency_table = frequency_table.cumsum()

    print(f'Frequency Table for {column}:\n{frequency_table}')
    print(f'\nCumulative Frequency Table for {column}:\n{cumulative_frequency_table}\n')
# Out:
# Descriptive Statistics for yr:
# count    123970.000000
# mean       2003.985634
# std          11.761904
# min        1975.000000
# 25%        1995.000000
# 50%        2005.000000
# 75%        2014.000000
# max        2023.000000
# Name: yr, dtype: float64
#
# Mean(Moy): 2003.9856336210373
# Median: 2005.0
# Mode: 2001
# Range: 48
# Variance: 138.34238731843502
# Standard Deviation: 11.76190406857814
# Frequency Table for yr:
#         yr
# 2015  3312
# 2007  3312
# 2020  3312
# 2019  3312
# 2018  3312
# 2017  3312
# 2016  3312
# 2014  3312
# 2013  3312
# 2012  3312
# 2011  3312
# 2010  3312
# 2009  3312
# 2008  3312
# 2006  3312
# 2005  3312
# 2004  3312
# 2003  3312
# 2002  3312
# 2001  3312
# 2021  3312
# 2022  3310
# 2000  3309
# 1999  3304
# 1998  3304
# 1997  3301
# 1996  3296
# 1995  3290
# 1994  3096
# 1993  3068
# 1992  3015
# 1991  2964
# 2023  2481
# 1990  1679
# 1989  1637
# 1988  1604
# 1987  1555
# 1986  1385
# 1985  1201
# 1984  1110
# 1983  1023
# 1982   940
# 1980   908
# 1981   898
# 1979   832
# 1978   702
# 1977   537
# 1976   391
# 1975   278
#
# Cumulative Frequency Table for yr:
#           yr
# 2015    3312
# 2007    6624
# 2020    9936
# 2019   13248
# 2018   16560
# 2017   19872
# 2016   23184
# 2014   26496
# 2013   29808
# 2012   33120
# 2011   36432
# 2010   39744
# 2009   43056
# 2008   46368
# 2006   49680
# 2005   52992
# 2004   56304
# 2003   59616
# 2002   62928
# 2001   66240
# 2021   69552
# 2022   72862
# 2000   76171
# 1999   79475
# 1998   82779
# 1997   86080
# 1996   89376
# 1995   92666
# 1994   95762
# 1993   98830
# 1992  101845
# 1991  104809
# 2023  107290
# 1990  108969
# 1989  110606
# 1988  112210
# 1987  113765
# 1986  115150
# 1985  116351
# 1984  117461
# 1983  118484
# 1982  119424
# 1980  120332
# 1981  121230
# 1979  122062
# 1978  122764
# 1977  123301
# 1976  123692
# 1975  123970
#
# Descriptive Statistics for period:
# count    123970.000000
# mean          2.620416
# std           1.436340
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          12.000000
# Name: period, dtype: float64
#
# Mean(Moy): 2.620416229733
# Median: 3.0
# Mode: 3
# Range: 11
# Variance: 2.0630716269595286
# Standard Deviation: 1.4363396628094376
# Frequency Table for period:
#     period
# 3    30613
# 2    30496
# 1    30364
# 4    29887
# 5      330
# 6      330
# 7      330
# 8      330
# 9      330
# 10     320
# 11     320
# 12     320
#
# Cumulative Frequency Table for period:
#     period
# 3    30613
# 2    61109
# 1    91473
# 4   121360
# 5   121690
# 6   122020
# 7   122350
# 8   122680
# 9   123010
# 10  123330
# 11  123650
# 12  123970
#
# Descriptive Statistics for index_nsa:
# count    123969.000000
# mean        178.196744
# std          97.409691
# min          18.520000
# 25%         109.420000
# 50%         160.160000
# 75%         215.190000
# max        1181.990000
# Name: index_nsa, dtype: float64
#
# Mean(Moy): 178.1967444280425
# Median: 160.16
# Mode: 100.0
# Range: 1163.47
# Variance: 9488.647942328535
# Standard Deviation: 97.40969121359812
# Frequency Table for index_nsa:
#         index_nsa
# 100.00        808
# 104.22         25
# 102.46         24
# 103.73         21
# 106.96         21
# ...           ...
# 426.42          1
# 471.87          1
# 484.65          1
# 494.78          1
# 211.86          1
#
# [33627 rows x 1 columns]
#
# Cumulative Frequency Table for index_nsa:
#         index_nsa
# 100.00        808
# 104.22        833
# 102.46        857
# 103.73        878
# 106.96        899
# ...           ...
# 426.42     123965
# 471.87     123966
# 484.65     123967
# 494.78     123968
# 211.86     123969
#
# [33627 rows x 1 columns]
#
# Descriptive Statistics for index_sa:
# count    41245.000000
# mean       199.669754
# std         92.208774
# min         74.790000
# 25%        131.880000
# 50%        183.390000
# 75%        237.340000
# max        828.160000
# Name: index_sa, dtype: float64
#
# Mean(Moy): 199.66975366711114
# Median: 183.39
# Mode: 100.0
# Range: 753.37
# Variance: 8502.457925630328
# Standard Deviation: 92.20877358272546
# Frequency Table for index_sa:
#         index_sa
# 100.00       300
# 100.07        15
# 101.06        11
# 99.79         11
# 99.17         11
# ...          ...
# 91.00          1
# 90.70          1
# 90.23          1
# 91.51          1
# 165.92         1
#
# [20789 rows x 1 columns]
#
# Cumulative Frequency Table for index_sa:
#         index_sa
# 100.00       300
# 100.07       315
# 101.06       326
# 99.79        337
# 99.17        348
# ...          ...
# 91.00      41241
# 90.70      41242
# 90.23      41243
# 91.51      41244
# 165.92     41245
#
# [20789 rows x 1 columns]

# %% [markdown]
# # UNI-VARIEES ANALYSIS FOR NON-NUMERICAL COLUMNS

# %%
# Univariate analysis for non-numerical columns
for column in non_numerical_columns:
    frequency_table = pd.DataFrame(df[column].value_counts())

    print(f'Frequency Table for {column}:\n{frequency_table}\n')

    # Plotting bar plot for non-numerical data
    plt.figure(figsize=(10, 5))
    sns.countplot(x=column, data=df)
    plt.title(f'Bar Plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=90)
    plt.show()

    # Pie chart for non-numerical data
    plt.figure(figsize=(8, 8))
    plt.pie(frequency_table[column], labels=frequency_table.index, autopct='%1.1f%%', startangle=140)
    plt.title(f'Pie Chart of {column}')
    plt.show()
# Out:
# Frequency Table for hpi_type:
#                hpi_type
# traditional      116768
# non-metro          5405
# distress-free      1572
# developmental       225
# Frequency Table for hpi_flavor:
#                   hpi_flavor
# all-transactions       82725
# purchase-only          26704
# expanded-data          14541
# Frequency Table for frequency:
#            frequency
# quarterly     120040
# monthly         3930
# Frequency Table for level:
#                         level
# MSA                     86533
# State                   28712
# USA or Census Division   8500
# Puerto Rico               225
# Frequency Table for place_name:
#                                place_name
# East North Central Division           850
# South Atlantic Division               850
# East South Central Division           850
# United States                         850
# West North Central Division           850
# ...                                   ...
# Johnstown, PA                         115
# Beckley, WV                           106
# California-Lexington Park, MD         104
# Hinesville, GA                         94
# The Villages, FL                       92
#
# [466 rows x 1 columns]
# Frequency Table for place_id:
#         place_id
# DV_ENC       850
# DV_SA        850
# DV_ESC       850
# USA          850
# DV_WNC       850
# ...          ...
# 27780        115
# 13220        106
# 15680        104
# 25980         94
# 45540         92
#
# [466 rows x 1 columns]
